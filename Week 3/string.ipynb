# %% [markdown]
# # string

# %%
greet = 'hello'
print(greet[1:4])
# Out:
# ell

# %% [markdown]
# # Access char

# %%
message = 'Hola Amigos'
print(message[0])
# Out:
# H

# %%
message = 'Hello dear'
message = 'Hello friends'
print(message)
# Out:
# Hello friends

# %% [markdown]
# # Multi string

# %%
message = '''
Myself Zulqarnain
And i am in the corvit
'''
print(message)
# Out:
# Myself Zulqarnain
# And i am in the corvit

# %% [markdown]
# # Compare str

# %%
str1 = 'Hello World'
str2 = 'Bye World'
str3 = 'Hello World'
print(str1==str2)
print(str1==str3)
print(str2==str3)
# Out:
# False
# True
# False

# %% [markdown]
# # combine str

# %%
greet = 'Hello'
name = 'Jack'
final = greet+ " " + name
print(final)
# Out:
# Hello Jack

# %% [markdown]
# # for loop

# %%
greet = 'hello'
for letter in greet:
    print(letter)
# Out:
# h
# e
# l
# l
# o

# %%
green = 'Its a color'
print(len(green))
# Out:
# 9

# %% [markdown]
# # Membership test

# %%
print('a' in 'hack')
print('A' in 'hack')
# Out:
# True
# False

# %% [markdown]
# # Built-in-functions

# %%
a = 'Myself Zulqarnain'
a.upper()
a.lower()
# Out:
# 'myself zulqarnain'

# %%
str = 'Python is fun'
print(str.partition('is'))
# Out:
# ('Python ', 'is', ' fun')

# %%
string = "Python is fun, isn't it"
print(string.partition('is'))
# Out:
# ('Python ', 'is', " fun, isn't it")

# %%
firstString = "abc"
secondString = "def"
string = "abc"
print(string.maketrans(firstString, secondString))
# Out:
# {97: 100, 98: 101, 99: 102}

# %%
text = 'Python is fun'
result = text.index('fun')
print(result)
# Out:
# 10
