# %%
cars = ('BMW','Tesla','Ford','Toyota')
print('Total Items:',len(cars))
# Out:
# Total Items: 4

# %%
fruits = ('banana','orange','apple')
for i in fruits:
    print(fruits)
# Out:
# ('banana', 'orange', 'apple')
# ('banana', 'orange', 'apple')
# ('banana', 'orange', 'apple')

# %%
colors = ('red','orange','blue')
print('yellow' in colors)
print('red' in colors)
# Out:
# False
# True

# %%
my_tuple = (10, 20, 30)
my_list = list(my_tuple)
my_list[1] = 50
my_tuple = tuple(my_list)
print(my_tuple)
# Out:
# (10, 50, 30)

# %%
my_tuple = (10, 20, 30)
my_tuple = my_tuple[:1] + (50,) + my_tuple[2:]
print(my_tuple)
# Out:
# (10, 50, 30)

# %%
greet = 'hello'
print(greet[1:4])
# Out:
# ell

# %%
greet = 'hello'
print(greet[-4])
# Out:
# e
