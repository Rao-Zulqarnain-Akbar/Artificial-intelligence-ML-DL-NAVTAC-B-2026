# %% [markdown]
# # Exercise1

# %%
dict = {'name':'Ali','age':18,'city':'Multan','institute':'Corvit'}
dict['country'] = 'Pakistan'
dict['age'] = 22
print(dict)
print(dict['city'])
# Out:
# {'name': 'Ali', 'age': 22, 'city': 'Multan', 'institute': 'Corvit', 'country': 'Pakistan'}
# Multan

# %% [markdown]
# # Exercise2

# %%
dict = {'name':'Ali','age':18,'city':'Multan','institute':'Corvit'}
del dict['institute']
print(dict)
dict['institute'] = 'Corvit'
print(dict)
if 'city' in dict:
    print("Key exist")
else:
    print("Key noy exist")
# Out:
# {'name': 'Ali', 'age': 18, 'city': 'Multan'}
# {'name': 'Ali', 'age': 18, 'city': 'Multan', 'institute': 'Corvit'}
# Key exist

# %% [markdown]
# # Exercise3

# %%
numbers = {"Ten":10,"Twenty":20,"Thirty":30}
num = {"Forty":40,"Fifty":50,"Sixty":60}
unite = numbers | num
print(unite)
# Out:
# {'Ten': 10, 'Twenty': 20, 'Thirty': 30, 'Forty': 40, 'Fifty': 50, 'Sixty': 60}

# %% [markdown]
# # Exercise4

# %%
string = 'NAVTAC'
empty = {}
for i in string:
    empty[i]=string.count(i)
print(empty)
# Out:
# {'N': 1, 'A': 2, 'V': 1, 'T': 1, 'C': 1}

# %% [markdown]
# # Exercise4 using nested for

# %%
string = "NAVTAC"
freq = {}
for i in string:
    count = 0
    for j in string:
        if i == j:
            count = count+1
    freq[i] = count
print(freq)
# Out:
# {'N': 1, 'A': 2, 'V': 1, 'T': 1, 'C': 1}
