# %%
id = [1,2,3,4]

# %%
eng = [70,80,90,60]

# %%
math = [90,90,80,80]

# %%
computer = [0,80,90,90]

# %%
for i in range(len(id)):
    total = eng[i] + math[i] + computer[i]
    average = total/3
    print('Id of student is',id[i])
    print('Total marks of each student',total)
    print('Average marks of each student',average)
    print('---------------------')
# Out:
# Id of student is 1
# Total marks of each student 160
# Average marks of each student 53.333333333333336
# ---------------------
# Id of student is 2
# Total marks of each student 250
# Average marks of each student 83.33333333333333
# ---------------------
# Id of student is 3
# Total marks of each student 260
# Average marks of each student 86.66666666666667
# ---------------------
# Id of student is 4
# Total marks of each student 230
# Average marks of each student 76.66666666666667
# ---------------------

# %%
thistuple = ('apple','banana','cherry')
print(len(thistuple))
updatedtuple = ('apple','cherry','banana','guaua')
print(updatedtuple)
print(updatedtuple[2])
print(append.tuple(
# Out:
# 3
# ('apple', 'cherry', 'banana', 'guaua')
# banana

# %%
thistuple = ('apple',)
print(type(thistuple))
# Out:
# <class 'tuple'>

# %%
vowels = ('a','e','i','o','i','u')
count = vowels.count('i')
print(count)
# Out:
# 2

# %%
numbers = (1,3,4,1,6,1)
count = numbers.count(1)
print('The count of 1 is:',count)
count = numbers.count(7)
print('The count of 7 is:',count)
# Out:
# The count of 1 is: 3
# The count of 7 is: 0

# %%
random = ('a',('a','b'),('a','b'),[3,4])
count = random.count(('a','b'))
print("The count of tuple ('a','b') is:", count)
count = random.count([3,4])
print("The count of list [3,4] is:", count)
# Out:
# The count of tuple ('a','b') is: 2
# The count of list [3,4] is: 1
